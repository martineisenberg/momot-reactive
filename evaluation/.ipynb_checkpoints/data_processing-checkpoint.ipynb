# %%
import seaborn as sns
import pandas as pd
import scipy.stats as st
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import warnings
from statistics import mean
import ast

warnings.filterwarnings('ignore')

# %% [markdown]
# # RQ1/2: Measurement of Quality

# %%
files = os.listdir(os.path.join('.', 'quality'))
mean = pd.DataFrame(columns = ["Option", "Naive Repair", "Replanning", "Replanning (seed 0.1)"])
std = pd.DataFrame(columns = ["Option", "Naive Repair", "Replanning", "Replanning (seed 0.1)"])
for f in files:
    if f.endswith("csv"):
        df = pd.read_csv(os.path.join('.', 'quality', f))
        mean_row = {}
        std_row = {}
        for name, group in df.groupby(by='variant'):
            #print(f"\tVariant: {name}")
            #print(f"\t\tFinal objective (mean): {group['final_objective_value'].mean():.3f} ({group['final_objective_value'].std():.3f})\n")
            if(name == "NSGAII_NaivePlanningStrategy_2"):
                mean_row["Naive Repair"] = round(group['final_objective_value'].mean(), 3)
                std_row["Naive Repair"] = round(group['final_objective_value'].std(), 3)
            elif(name == "NSGAII_EvaluationReplanningStrategy-10000_1"):
                mean_row["Replanning"] = round(group['final_objective_value'].mean(), 3)
                std_row["Replanning"] = round(group['final_objective_value'].std(), 3)
            elif(name == "NSGAII_EvaluationReplanningStrategy-10000reusePortion=0.2_withReinit_0"):
                mean_row["Replanning (seed 0.1)"] = round(group['final_objective_value'].mean(), 3)
                std_row["Replanning (seed 0.1)"] = round(group['final_objective_value'].std(), 3)
           
        #print(f)
       # print(mean_row)
        mean_row["Option"] = f.split("@")[1].split(".")[0]
        mean = mean.append(mean_row, ignore_index = True)
        std_row["Option"] = f.split("@")[1].split(".")[0]
        std = std.append(std_row, ignore_index = True)
            # todo: median
            # todo: variance
print("Mean - Absolute Values")
display(mean)

mean["Replanning"] = (mean["Replanning"] - mean["Naive Repair"]) / mean["Naive Repair"] * 100
mean.round({'Replanning': 1})
mean["Replanning (seed 0.1)"] = (mean["Replanning (seed 0.1)"] - mean["Naive Repair"])/ mean["Naive Repair"] * 100
mean.round(3)
print("Mean - Values relative to Naive Repair (in %)")
display(mean)

print("Standard Deviation - Absolut Values")
display(std)
#print(std)
# todo: create table for each rq
# todo: create plot for each rq

# todo: in den CSVs: naive Planning -> naive Repair
# Out:
# Mean - Absolute Values
#                                Option  Naive Repair  Replanning  \
# 0   OPTIMALITY_ERROR_FIRST_10_PERCENT        20.444      20.249
# 1    OPTIMALITY_ERROR_LAST_10_PERCENT        20.512      17.939
# 2  OPTIMALITY_ERROR_MIDDLE_10_PERCENT        20.465      19.537
# 3        STRONG_ERROR_LAST_10_PERCENT        14.467      11.641
# 4      STRONG_ERROR_MIDDLE_10_PERCENT        14.995      13.019
#
#    Replanning (seed 0.1)
# 0                 19.984
# 1                 20.656
# 2                 20.307
# 3                 14.155
# 4                 14.728
# Mean - Values relative to Naive Repair (in %)
#                                Option  Naive Repair  Replanning  \
# 0   OPTIMALITY_ERROR_FIRST_10_PERCENT        20.444   -0.953825
# 1    OPTIMALITY_ERROR_LAST_10_PERCENT        20.512  -12.543877
# 2  OPTIMALITY_ERROR_MIDDLE_10_PERCENT        20.465   -4.534571
# 3        STRONG_ERROR_LAST_10_PERCENT        14.467  -19.534112
# 4      STRONG_ERROR_MIDDLE_10_PERCENT        14.995  -13.177726
#
#    Replanning (seed 0.1)
# 0              -2.250049
# 1               0.702028
# 2              -0.772050
# 3              -2.156632
# 4              -1.780594
# Standard Deviation - Absolut Values
#                                Option  Naive Repair  Replanning  \
# 0   OPTIMALITY_ERROR_FIRST_10_PERCENT         0.805       0.945
# 1    OPTIMALITY_ERROR_LAST_10_PERCENT         0.693       0.939
# 2  OPTIMALITY_ERROR_MIDDLE_10_PERCENT         0.498       0.872
# 3        STRONG_ERROR_LAST_10_PERCENT         1.344       1.104
# 4      STRONG_ERROR_MIDDLE_10_PERCENT         1.247       1.133
#
#    Replanning (seed 0.1)
# 0                  0.642
# 1                  0.695
# 2                  0.872
# 3                  1.059
# 4                  1.435

# %%
files = os.listdir(os.path.join('.', 'iterations'))
mean = pd.DataFrame(columns = ["Option", "Naive Repair", "Replanning", "Replanning (seed 0.1)"])
std = pd.DataFrame(columns = ["Option", "Naive Repair", "Replanning", "Replanning (seed 0.1)"])
mean_improvement = pd.DataFrame(columns = ["Option", "Naive Repair", "Replanning", "Replanning (seed 0.1)"])

for f in files:
    if f.endswith("csv"):
        df = pd.read_csv(os.path.join('.', 'iterations', f))
        mean_row = {}
        std_row = {}
        mean_impr_row= {}
        for name, group in df.groupby(by='variant'):
            #print(f"\tVariant: {name}")
            #print(f"\t\tFinal objective (mean): {group['final_objective_value'].mean():.3f} ({group['final_objective_value'].std():.3f})\n")
            if(name == "NSGAII_NaivePlanningStrategy_2"):
                mean_row["Naive Repair"] = round(group['final_objective_value'].mean(), 3)
                mean_row["Naive Repair"] = round(group['final_objective_value'].mean(), 3)
                std_row["Naive Repair"] = round(group['final_objective_value'].std(), 3)
            elif(name == "NSGAII_EvaluationReplanningStrategy-10000_1"):
                mean_row["Replanning"] = round(group['final_objective_value'].mean(), 3)
                std_row["Replanning"] = round(group['final_objective_value'].std(), 3)
            elif(name == "NSGAII_EvaluationReplanningStrategy-10000reusePortion=0.2_withReinit_0"):
                mean_row["Replanning (seed 0.1)"] = round(group['final_objective_value'].mean(), 3)
                std_row["Replanning (seed 0.1)"] = round(group['final_objective_value'].std(), 3)
           
        #print(f)
       # print(mean_row)
        mean_row["Option"] = f.split("@")[1].split(".")[0]
        mean = mean.append(mean_row, ignore_index = True)
        std_row["Option"] = f.split("@")[1].split(".")[0]
        std = std.append(std_row, ignore_index = True)
            # todo: median
            # todo: variance
print("Mean - Absolute Values")
display(mean)

mean["Replanning"] = (mean["Replanning"] - mean["Naive Repair"]) / mean["Naive Repair"] * 100
mean.round({'Replanning': 1})
mean["Replanning (seed 0.1)"] = (mean["Replanning (seed 0.1)"] - mean["Naive Repair"])/ mean["Naive Repair"] * 100
mean.round(3)
print("Mean - Values relative to Naive Repair (in %)")
display(mean)

print("Standard Deviation - Absolut Values")
display(std)
#print(std)
# todo: create table for each rq
# todo: create plot for each rq

# todo: in den CSVs: naive Planning -> naive Repair
# Out:
# Mean - Absolute Values
#                                Option  Naive Repair  Replanning  \
# 0   OPTIMALITY_ERROR_FIRST_10_PERCENT        20.606      20.175
# 1    OPTIMALITY_ERROR_LAST_10_PERCENT        20.492      18.449
# 2  OPTIMALITY_ERROR_MIDDLE_10_PERCENT        20.484      19.297
# 3       STRONG_ERROR_FIRST_10_PERCENT        15.714      14.666
# 4        STRONG_ERROR_LAST_10_PERCENT        14.184      11.627
# 5      STRONG_ERROR_MIDDLE_10_PERCENT        14.930      13.225
#
#    Replanning (seed 0.1)
# 0                 20.128
# 1                 20.165
# 2                 20.277
# 3                 15.096
# 4                 14.550
# 5                 14.385
# Mean - Values relative to Naive Repair (in %)
#                                Option  Naive Repair  Replanning  \
# 0   OPTIMALITY_ERROR_FIRST_10_PERCENT        20.606   -2.091624
# 1    OPTIMALITY_ERROR_LAST_10_PERCENT        20.492   -9.969744
# 2  OPTIMALITY_ERROR_MIDDLE_10_PERCENT        20.484   -5.794767
# 3       STRONG_ERROR_FIRST_10_PERCENT        15.714   -6.669212
# 4        STRONG_ERROR_LAST_10_PERCENT        14.184  -18.027355
# 5      STRONG_ERROR_MIDDLE_10_PERCENT        14.930  -11.419960
#
#    Replanning (seed 0.1)
# 0              -2.319713
# 1              -1.595745
# 2              -1.010545
# 3              -3.932799
# 4               2.580372
# 5              -3.650368
# Standard Deviation - Absolut Values
#                                Option  Naive Repair  Replanning  \
# 0   OPTIMALITY_ERROR_FIRST_10_PERCENT         0.716       0.745
# 1    OPTIMALITY_ERROR_LAST_10_PERCENT         0.659       0.586
# 2  OPTIMALITY_ERROR_MIDDLE_10_PERCENT         0.812       0.869
# 3       STRONG_ERROR_FIRST_10_PERCENT         1.095       1.097
# 4        STRONG_ERROR_LAST_10_PERCENT         1.161       1.233
# 5      STRONG_ERROR_MIDDLE_10_PERCENT         1.533       1.377
#
#    Replanning (seed 0.1)
# 0                  0.649
# 1                  0.633
# 2                  0.755
# 3                  1.510
# 4                  1.387
# 5                  1.608

# %% [markdown]
# # RQ2: Measurement of Evaluations/Time
# ### Predefined standard deviation ( >= 50% decrease from initial std); Search until quality is sufficient (for initial plan & when replanning after disturbance)

# %%
files = os.listdir(os.path.join('.', 'threshold_rq1_rq2'))
mean = pd.DataFrame(columns = ["Option", "Replanning", "Replanning (seed 0.2)"])
std = pd.DataFrame(columns = ["Option", "Replanning", "Replanning (seed 0.2)"])
for f in files:
    if f.endswith("csv"):
        df = pd.read_csv(os.path.join('.', 'threshold_rq1_rq2', f))
        mean_row = {}
        std_row = {}
        for name, group in df.groupby(by='variant'):
            #print(f"\tVariant: {name}")
            #print(f"\t\tFinal objective (mean): {group['final_objective_value'].mean():.3f} ({group['final_objective_value'].std():.3f})\n")
            if(name == "NSGAII_PlanningStrategy-ReplanningStrategy_reuse0.10_1"):
                mean_row["Replanning"] = round(group['last_replanning_time'].mean(), 3)
                std_row["Replanning"] = round(group['last_replanning_time'].std(), 3)
            elif(name == "NSGAII_PlanningStrategy-ReplanningStrategy_0"):
                mean_row["Replanning (seed 0.2)"] = round(group['last_replanning_time'].mean(), 3)
                std_row["Replanning (seed 0.2)"] = round(group['last_replanning_time'].std(), 3)
           
        #print(f)
       # print(mean_row)
        mean_row["Option"] = f.split("@")[1].split("_errPerDisturbance")[0]
        mean = mean.append(mean_row, ignore_index = True)
        std_row["Option"] = f.split("@")[1].split(".")[0]
        std = std.append(std_row, ignore_index = True)
            # todo: median
            # todo: variance
print("Mean - Replanning time")
display(mean)

#mean["Replanning"] = (mean["Replanning"] - mean["Naive Repair"]) / mean["Naive Repair"] * 100
#mean.round({'Replanning': 1})
mean["Replanning (seed 0.2)"] = (mean["Replanning (seed 0.2)"] - mean["Replanning"])/ mean["Replanning"] * 100
mean.round(3)
print("Mean - Replanning time (with seed) relative to plain replanning (in %)")
display(mean)

print("Standard Deviation - Replanning time")
display(std)
#print(std)
# todo: create table for each rq
# todo: create plot for each rq

# todo: in den CSVs: naive Planning -> naive Repair
# Out:
# Mean - Replanning time
#                             Option  Replanning  Replanning (seed 0.2)
# 0      ADD_STACKS_FIRST_10_PERCENT     325.024                129.279
# 1     ADD_STACKS_MIDDLE_10_PERCENT     334.345                 82.029
# 2       ADD_STACKS_LAST_10_PERCENT     333.981                 55.898
# 3    REMOVE_STACKS_LAST_10_PERCENT       8.047                 42.132
# 4   REMOVE_STACKS_FIRST_10_PERCENT      26.002                 64.264
# 5  REMOVE_STACKS_MIDDLE_10_PERCENT      34.088                 51.267
# Mean - Replanning time (with seed) relative to plain replanning (in %)
#                             Option  Replanning  Replanning (seed 0.2)
# 0      ADD_STACKS_FIRST_10_PERCENT     325.024             -60.224783
# 1     ADD_STACKS_MIDDLE_10_PERCENT     334.345             -75.465761
# 2       ADD_STACKS_LAST_10_PERCENT     333.981             -83.263120
# 3    REMOVE_STACKS_LAST_10_PERCENT       8.047             423.574003
# 4   REMOVE_STACKS_FIRST_10_PERCENT      26.002             147.150219
# 5  REMOVE_STACKS_MIDDLE_10_PERCENT      34.088              50.396034
# Standard Deviation - Replanning time
#                                               Option  Replanning  \
# 0    ADD_STACKS_FIRST_10_PERCENT_errPerDisturbance-5     496.630
# 1   ADD_STACKS_MIDDLE_10_PERCENT_errPerDisturbance-5     453.262
# 2     ADD_STACKS_LAST_10_PERCENT_errPerDisturbance-5     183.341
# 3  REMOVE_STACKS_LAST_10_PERCENT_errPerDisturbance-5      24.415
# 4  REMOVE_STACKS_FIRST_10_PERCENT_errPerDisturban...      25.543
# 5  REMOVE_STACKS_MIDDLE_10_PERCENT_errPerDisturba...      64.798
#
#    Replanning (seed 0.2)
# 0                188.604
# 1                 79.778
# 2                 15.648
# 3                  7.271
# 4                 17.988
# 5                 10.209

# %% [markdown]
# # RQ3: Parallel Replanning
# ### Predefined standard deviation ( >= 50% decrease from initial std + initialization approximate);
# * Always plan until std < initial_std*.5
# * Replanning for 2/5/10 steps: Replan for at least steps*T seconds; Terminate if threshold satisfied, otherwise search
# * Always pick solution with least steps
# * T=10s

# %%
T = 10
files = os.listdir(os.path.join('.', 'parallel_rq3'))
overall_runtime = pd.DataFrame(columns = ["Option", "Idle Replan", "Parallel (2)", "Parallel (5)", "Parallel (10)"])
overall_runtime_std = pd.DataFrame(columns =  ["Option", "Idle Replan",  "Parallel (2)", "Parallel (5)", "Parallel (10)"])
for f in files:
    if f.endswith("csv"):
        df = pd.read_csv(os.path.join('.', 'parallel_rq3', f), sep=";")
        df_p = pd.read_csv(os.path.join('.', 'parallel_rq3', "parallel_results", f[:-4] + "_predictive.csv"), sep=";")
        
        ## reenumerate predictive run rows from 0,1,2,3,4,5 to 0,0,0, 1,1,1, ...
        df_p['run'] = df_p['run'].map(int)/3
        df_p["run"] = df_p["run"].map(int)
        
        step_variants = df_p["predicted_steps"].unique()
        
        ## get idle computed objs from predictive run file
        idle_computed_objs = []
        for idx, row in df.iterrows():
            #if not df_p.loc[df_p["run"] == row['run']].empty:
                #idle_computed_objs
                #print(df_p.loc[df_p["run"] == row['run']].iloc[0]["idle_computed_objectives"])
            idle_computed_objs.append(df_p.loc[df_p["run"] == row['run']].iloc[0]["idle_computed_objectives"])
 
        df["idle_computed_objectives"] = idle_computed_objs
        df["idle_computed_steps"] = [ast.literal_eval(g)[1] for g in idle_computed_objs]
        df["idle_computed_steps_execution_time"] = [ast.literal_eval(g)[1]*T for g in idle_computed_objs]
        df["overall_execution_time"] =  df["idle_computed_steps_execution_time"] + df["last_replanning_time"]
       # print(df)
        mean_executiontime_row = {}
        std_executiontime_row = {}

        df_p["pred_plan_steps"] = [ast.literal_eval(g)[1] for g in df_p["pred_plan_objectives"]]
        df_p["pred_plan_steps_execution_time"] = [ast.literal_eval(g)[1]*T for g in df_p["pred_plan_objectives"]]
        df_p["pred_overall_execution_time"] =  df_p["pred_plan_steps_execution_time"] + df_p["pred_plan_runtime"]

        for name, g in df.groupby(by='variant'):

            mean_executiontime_row["Idle Replan"] = round(g['overall_execution_time'].mean(),3)
            std_executiontime_row["Idle Replan"] = round(g['overall_execution_time'].std(),3)/mean_executiontime_row["Idle Replan"]*100            
            
        for name, group in df_p.groupby(by=['variant', 'predicted_steps']):
           
            mean_executiontime_row[f"Parallel ({name[1]})"] = round(group['pred_overall_execution_time'].mean(), 3)
            std_executiontime_row[f"Parallel ({name[1]})"] = round(group['pred_overall_execution_time'].std(), 3)/mean_executiontime_row[f"Parallel ({name[1]})"]*100
   
      
        mean_executiontime_row["Option"] = f.split("@")[1].split("_errPerDisturbance")[0]
        std_executiontime_row["Option"] = f.split("@")[1].split("_errPerDisturbance")[0]
        overall_runtime = overall_runtime.append(mean_executiontime_row, ignore_index = True)
        overall_runtime_std = overall_runtime_std.append(std_executiontime_row, ignore_index = True)

        
print("Mean - Execution time (seconds)")
display(overall_runtime.iloc[:2, :])
display(overall_runtime.iloc[2:, :])

for steps in step_variants:
    overall_runtime[f"Parallel ({steps})"] = (overall_runtime[f"Parallel ({steps})"] - overall_runtime["Idle Replan"])/ overall_runtime["Idle Replan"] * 100

#mean.round({'Replanning': 1})
#mean["Replanning (seed 0.2)"] = (mean["Replanning (seed 0.2)"] - mean["Replanning"])/ mean["Replanning"] * 100
#mean.round(3)
#print("Mean - Replanning time (with seed) relative to plain replanning (in %)")
print("Mean - Execution time relative to idle replanning (%)")
display(overall_runtime.iloc[:2, :])
display(overall_runtime.iloc[2:, :])

print("Standard Deviation - Execution time (seconds)")
#overall_runtime_std.iloc[:, 1:] = overall_runtime_std[:, 1:]/overall_runtime[:, 1:]

display(overall_runtime_std.iloc[:2, :])
display(overall_runtime_std.iloc[2:, :])
# todo: create table for each rq
# todo: create plot for each rq

# todo: in den CSVs: naive Planning -> naive Repair
# Out:
# Mean - Execution time (seconds)
#                          Option  Idle Replan  Parallel (2)  Parallel (5)  \
# 0   ADD_STACKS_FIRST_10_PERCENT      563.889       578.132       762.692
# 1  ADD_STACKS_MIDDLE_10_PERCENT      632.978       547.846       578.665
#
#    Parallel (10)
# 0        479.386
# 1        451.062
#                             Option  Idle Replan  Parallel (2)  Parallel (5)  \
# 2   REMOVE_STACKS_FIRST_10_PERCENT      591.166       555.898       516.868
# 3  REMOVE_STACKS_MIDDLE_10_PERCENT      618.172       657.992       537.906
#
#    Parallel (10)
# 2        296.399
# 3        279.427
# Mean - Execution time relative to idle replanning (%)
#                          Option  Idle Replan  Parallel (2)  Parallel (5)  \
# 0   ADD_STACKS_FIRST_10_PERCENT      563.889      2.525852     35.255697
# 1  ADD_STACKS_MIDDLE_10_PERCENT      632.978    -13.449441     -8.580551
#
#    Parallel (10)
# 0     -14.985751
# 1     -28.739703
#                             Option  Idle Replan  Parallel (2)  Parallel (5)  \
# 2   REMOVE_STACKS_FIRST_10_PERCENT      591.166     -5.965837    -12.568043
# 3  REMOVE_STACKS_MIDDLE_10_PERCENT      618.172      6.441573    -12.984412
#
#    Parallel (10)
# 2     -49.861968
# 3     -54.797856
# Standard Deviation - Execution time (seconds)
#                          Option  Idle Replan  Parallel (2)  Parallel (5)  \
# 0   ADD_STACKS_FIRST_10_PERCENT    28.840073     27.282697     75.450903
# 1  ADD_STACKS_MIDDLE_10_PERCENT    24.636243     35.273964     30.111550
#
#    Parallel (10)
# 0      39.859946
# 1      45.805676
#                             Option  Idle Replan  Parallel (2)  Parallel (5)  \
# 2   REMOVE_STACKS_FIRST_10_PERCENT    33.225016     27.716056     31.213192
# 3  REMOVE_STACKS_MIDDLE_10_PERCENT    28.592204     37.498632     44.704837
#
#    Parallel (10)
# 2      21.825310
# 3      42.569258

# %%
T = 10
files = os.listdir(os.path.join('.', 'parallel_rq3'))
overall_runtime = pd.DataFrame(columns = ["Option", "Idle Replan", "Parallel (2)", "Parallel (5)", "Parallel (10)"])
overall_runtime_std = pd.DataFrame(columns =  ["Option", "Idle Replan",  "Parallel (2)", "Parallel (5)", "Parallel (10)"])
for f in files:
    if f.endswith("csv"):
        df = pd.read_csv(os.path.join('.', 'parallel_rq3', f), sep=";")
        df_p = pd.read_csv(os.path.join('.', 'parallel_rq3', "parallel_results", f[:-4] + "_predictive.csv"), sep=";")
        
        ## reenumerate predictive run rows from 0,1,2,3,4,5 to 0,0,0, 1,1,1, ...
        df_p['run'] = df_p['run'].map(int)/3
        df_p["run"] = df_p["run"].map(int)
        
        step_variants = df_p["predicted_steps"].unique()
        
        ## get idle computed objs from predictive run file
        idle_computed_objs = []
        for idx, row in df.iterrows():
            #if not df_p.loc[df_p["run"] == row['run']].empty:
                #idle_computed_objs
                #print(df_p.loc[df_p["run"] == row['run']].iloc[0]["idle_computed_objectives"])
            idle_computed_objs.append(df_p.loc[df_p["run"] == row['run']].iloc[0]["idle_computed_objectives"])
 
        df["idle_computed_objectives"] = idle_computed_objs
        df["idle_computed_steps"] = [ast.literal_eval(g)[1] for g in idle_computed_objs]
        df["idle_computed_steps_execution_time"] = [ast.literal_eval(g)[1]*T for g in idle_computed_objs]
        df["overall_execution_time"] =  df["idle_computed_steps_execution_time"] + df["last_replanning_time"]
       # print(df)
        mean_executiontime_row = {}
        std_executiontime_row = {}

        df_p["pred_plan_steps"] = [ast.literal_eval(g)[1] for g in df_p["pred_plan_objectives"]]
        df_p["pred_plan_steps_execution_time"] = [ast.literal_eval(g)[1]*T for g in df_p["pred_plan_objectives"]]
        df_p["pred_overall_execution_time"] =  df_p["pred_plan_steps_execution_time"] + df_p["pred_plan_runtime"]

        for name, g in df.groupby(by='variant'):

            mean_executiontime_row["Idle Replan"] = round(g['overall_execution_time'].median(),3)
            std_executiontime_row["Idle Replan"] = round(g['overall_execution_time'].std(),3)            
            
        for name, group in df_p.groupby(by=['variant', 'predicted_steps']):
           
            mean_executiontime_row[f"Parallel ({name[1]})"] = round(group['pred_overall_execution_time'].median(), 3)
            std_executiontime_row[f"Parallel ({name[1]})"] = round(group['pred_overall_execution_time'].std(), 3)
   
      
        mean_executiontime_row["Option"] = f.split("@")[1].split("_errPerDisturbance")[0]
        std_executiontime_row["Option"] = f.split("@")[1].split("_errPerDisturbance")[0]
        overall_runtime = overall_runtime.append(mean_executiontime_row, ignore_index = True)
        overall_runtime_std = overall_runtime_std.append(std_executiontime_row, ignore_index = True)

        
print("Median - Execution time (seconds)")
display(overall_runtime.iloc[:2, :])
display(overall_runtime.iloc[2:, :])

for steps in step_variants:
    overall_runtime[f"Parallel ({steps})"] = (overall_runtime[f"Parallel ({steps})"] - overall_runtime["Idle Replan"])/ overall_runtime["Idle Replan"] * 100

#mean.round({'Replanning': 1})
#mean["Replanning (seed 0.2)"] = (mean["Replanning (seed 0.2)"] - mean["Replanning"])/ mean["Replanning"] * 100
#mean.round(3)
#print("Mean - Replanning time (with seed) relative to plain replanning (in %)")
print("Median - Execution time relative to idle replanning (%)")
display(overall_runtime.iloc[:2, :])
display(overall_runtime.iloc[2:, :])

print("Standard Deviation - Execution time (seconds)")

display(overall_runtime_std.iloc[:2, :])
display(overall_runtime_std.iloc[2:, :])
# todo: create table for each rq
# todo: create plot for each rq

# todo: in den CSVs: naive Planning -> naive Repair
# Out:
# Median - Execution time (seconds)
#                          Option  Idle Replan  Parallel (2)  Parallel (5)  \
# 0   ADD_STACKS_FIRST_10_PERCENT      521.915       545.965       609.744
# 1  ADD_STACKS_MIDDLE_10_PERCENT      588.101       502.324       512.091
#
#    Parallel (10)
# 0        425.146
# 1        420.587
#                             Option  Idle Replan  Parallel (2)  Parallel (5)  \
# 2   REMOVE_STACKS_FIRST_10_PERCENT      545.351       538.186       467.768
# 3  REMOVE_STACKS_MIDDLE_10_PERCENT      585.096       598.230       510.206
#
#    Parallel (10)
# 2        290.092
# 3        240.115
# Median - Execution time relative to idle replanning (%)
#                          Option  Idle Replan  Parallel (2)  Parallel (5)  \
# 0   ADD_STACKS_FIRST_10_PERCENT      521.915       4.60803     16.828219
# 1  ADD_STACKS_MIDDLE_10_PERCENT      588.101     -14.58542    -12.924651
#
#    Parallel (10)
# 0     -18.541142
# 1     -28.483883
#                             Option  Idle Replan  Parallel (2)  Parallel (5)  \
# 2   REMOVE_STACKS_FIRST_10_PERCENT      545.351     -1.313833    -14.226251
# 3  REMOVE_STACKS_MIDDLE_10_PERCENT      585.096      2.244760    -12.799609
#
#    Parallel (10)
# 2     -46.806369
# 3     -58.961435
# Standard Deviation - Execution time (seconds)
#                          Option  Idle Replan  Parallel (2)  Parallel (5)  \
# 0   ADD_STACKS_FIRST_10_PERCENT      162.626       157.730       575.458
# 1  ADD_STACKS_MIDDLE_10_PERCENT      155.942       193.247       174.245
#
#    Parallel (10)
# 0        191.083
# 1        206.612
#                             Option  Idle Replan  Parallel (2)  Parallel (5)  \
# 2   REMOVE_STACKS_FIRST_10_PERCENT      196.415       154.073       161.331
# 3  REMOVE_STACKS_MIDDLE_10_PERCENT      176.749       246.738       240.470
#
#    Parallel (10)
# 2          64.69
# 3         118.95
