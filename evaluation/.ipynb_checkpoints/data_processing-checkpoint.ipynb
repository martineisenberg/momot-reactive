# %%
import seaborn as sns
import pandas as pd
import scipy.stats as st
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import warnings
from statistics import mean
import ast

warnings.filterwarnings('ignore')

# %% [markdown]
# # RQ1/2: Measurement of Quality

# %%
files = os.listdir(os.path.join('.', 'quality/max10itemsperstack'))
mean = pd.DataFrame(columns = ["Option", "Initial Plan", "Initial Plan after Disturbance", "Naive Repair", "Replanning", "Replanning (seed 0.2)"])
std = pd.DataFrame(columns = ["Option", "Naive Repair", "Replanning", "Replanning (seed 0.2)"])
for f in files:
    if f.endswith("csv"):
        df = pd.read_csv(os.path.join('.', 'quality/max10itemsperstack', f))
        mean_row = {}
        std_row = {}
        for name, group in df.groupby(by='variant'):
            if(name == "NSGAII_NaivePlanningStrategy_2"):
                mean_row["Naive Repair"] = round(group['final_objective_value'].mean(), 3)
                mean_row["Initial Plan"] = round(group['initial_planning_objective'].mean(), 3)
                mean_row["Initial Plan after Disturbance"] = round(group['initial_post_disturbance_std'].mean(), 3)
                std_row["Naive Repair"] = round(group['final_objective_value'].std(), 3)
            elif(name == "NSGAII_EvaluationReplanningStrategy-10000_1" or name == "NSGAII_EvaluationReplanningStrategy-10000_0"):
                mean_row["Replanning"] = round(group['final_objective_value'].mean(), 3)
                std_row["Replanning"] = round(group['final_objective_value'].std(), 3)
            elif(name == "NSGAII_EvaluationReplanningStrategy-10000reusePortion=0.2_withReinit_0" or name == "NSGAII_EvaluationReplanningStrategy-10000reusePortion=0.2_withSeed_1"):
                mean_row["Replanning (seed 0.2)"] = round(group['final_objective_value'].mean(), 3)
                std_row["Replanning (seed 0.2)"] = round(group['final_objective_value'].std(), 3)
           
        mean_row["Option"] = f.split("@")[1].split(".")[0]
        mean = mean.append(mean_row, ignore_index = True)
        std_row["Option"] = f.split("@")[1].split(".")[0]
        std = std.append(std_row, ignore_index = True)
            # todo: median
            # todo: variance
print("Mean - Absolute Values")
display(mean)

print("Standard Deviation - Absolut Values")
display(std)
#print(std)
# todo: create table for each rq
# todo: create plot for each rq

# todo: in den CSVs: naive Planning -> naive Repair
# Out:
# Mean - Absolute Values
#                                               Option Initial Plan  \
# 0    ADD_STACKS_FIRST_10_PERCENT_errPerDisturbance-5        1.693
# 1     ADD_STACKS_LAST_10_PERCENT_errPerDisturbance-5        1.713
# 2   ADD_STACKS_MIDDLE_10_PERCENT_errPerDisturbance-5        1.744
# 3  REMOVE_STACKS_FIRST_10_PERCENT_errPerDisturban...        1.717
# 4  REMOVE_STACKS_LAST_10_PERCENT_errPerDisturbance-5        1.715
# 5  REMOVE_STACKS_MIDDLE_10_PERCENT_errPerDisturba...        1.715
#
#   Initial Plan after Disturbance Naive Repair Replanning Replanning (seed 0.2)
# 0                           3.36        2.202      2.017                 2.171
# 1                          2.315        2.182       1.71                 2.163
# 2                          3.027        2.226      1.881                 2.169
# 3                          3.108        1.839      1.615                  1.74
# 4                           1.89        1.742      1.386                 1.702
# 5                          2.754        1.803       1.47                 1.755
# Mean - Values relative to Naive Repair (in %)
#                                               Option Initial Plan  \
# 0    ADD_STACKS_FIRST_10_PERCENT_errPerDisturbance-5        1.693
# 1     ADD_STACKS_LAST_10_PERCENT_errPerDisturbance-5        1.713
# 2   ADD_STACKS_MIDDLE_10_PERCENT_errPerDisturbance-5        1.744
# 3  REMOVE_STACKS_FIRST_10_PERCENT_errPerDisturban...        1.717
# 4  REMOVE_STACKS_LAST_10_PERCENT_errPerDisturbance-5        1.715
# 5  REMOVE_STACKS_MIDDLE_10_PERCENT_errPerDisturba...        1.715
#
#   Initial Plan after Disturbance Naive Repair Replanning Replanning (seed 0.2)
# 0                           3.36        2.202  -8.401453             -1.407811
# 1                          2.315        2.182 -21.631531             -0.870761
# 2                          3.027        2.226 -15.498652             -2.560647
# 3                          3.108        1.839 -12.180533             -5.383361
# 4                           1.89        1.742  -20.43628             -2.296211
# 5                          2.754        1.803 -18.469218              -2.66223
# Standard Deviation - Absolut Values
#                                               Option Naive Repair Replanning  \
# 0    ADD_STACKS_FIRST_10_PERCENT_errPerDisturbance-5        0.106      0.098
# 1     ADD_STACKS_LAST_10_PERCENT_errPerDisturbance-5        0.125      0.116
# 2   ADD_STACKS_MIDDLE_10_PERCENT_errPerDisturbance-5        0.119       0.09
# 3  REMOVE_STACKS_FIRST_10_PERCENT_errPerDisturban...        0.153      0.145
# 4  REMOVE_STACKS_LAST_10_PERCENT_errPerDisturbance-5        0.141      0.128
# 5  REMOVE_STACKS_MIDDLE_10_PERCENT_errPerDisturba...        0.142      0.139
#
#   Replanning (seed 0.2)
# 0                 0.091
# 1                 0.084
# 2                 0.111
# 3                 0.115
# 4                 0.162
# 5                 0.208

# %%
mean_relative = pd.DataFrame(columns = ["Option", "Diff Initial after Disturbance", "Diff Naive Repair to Initial", 
                                       "Diff Replanning to Naive Repair", "Diff seed 0.2 to no seed"])
mean_relative["Diff Initial after Disturbance"] = (mean["Initial Plan after Disturbance"] - mean["Initial Plan"]) / mean["Initial Plan"] * 100
mean_relative["Diff Naive Repair to Initial"] = (mean["Naive Repair"] - mean["Initial Plan"]) / mean["Initial Plan"] * 100
mean_relative["Diff Replanning to Naive Repair"] = (mean["Replanning"] - mean["Naive Repair"])/ mean["Naive Repair"] * 100
mean_relative["Diff seed 0.2 to no seed"] = (mean["Replanning (seed 0.2)"] - mean["Replanning"])/ mean["Replanning"] * 100
mean_relative["Option"] = mean["Option"]
mean_relative.round(3)
display(mean_relative)
# Out:
#                                               Option  \
# 0    ADD_STACKS_FIRST_10_PERCENT_errPerDisturbance-5
# 1     ADD_STACKS_LAST_10_PERCENT_errPerDisturbance-5
# 2   ADD_STACKS_MIDDLE_10_PERCENT_errPerDisturbance-5
# 3  REMOVE_STACKS_FIRST_10_PERCENT_errPerDisturban...
# 4  REMOVE_STACKS_LAST_10_PERCENT_errPerDisturbance-5
# 5  REMOVE_STACKS_MIDDLE_10_PERCENT_errPerDisturba...
#
#   Diff Initial after Disturbance Diff Naive Repair to Initial  \
# 0                      98.464265                    30.064973
# 1                      35.143024                    27.378867
# 2                      73.566514                    27.637615
# 3                      81.013395                     7.105416
# 4                      10.204082                     1.574344
# 5                       60.58309                     5.131195
#
#   Diff Replanning to Naive Repair Diff seed 0.2 to no seed
# 0                     -481.537385               -83.243243
# 1                    -1091.362544               -95.974576
# 2                     -796.255718               -83.478261
# 3                     -762.345454               -55.803571
# 4                     -1273.15041               -88.764045
# 5                    -1124.360398               -85.585586

# %% [markdown]
# # RQ2: Measurement of Evaluations/Time
# ### Predefined standard deviation ( >= 50% decrease from initial std); Search until quality is sufficient (for initial plan & when replanning after disturbance)

# %%
files = os.listdir(os.path.join('.', 'threshold_rq1_rq2'))
mean = pd.DataFrame(columns = ["Option", "Replanning", "Replanning (seed 0.2)", "Diff to no seed"])
std = pd.DataFrame(columns = ["Option", "Replanning", "Replanning (seed 0.2)"])
for f in files:
    if f.endswith("csv"):
        df = pd.read_csv(os.path.join('.', 'threshold_rq1_rq2', f))
        print(df.columns)
        mean_row = {}
        std_row = {}
        for name, group in df.groupby(by='variant'):
            if(name == "NSGAII_ConditionReplanningStrategy-_0-13.6795_0"):
                mean_row["Replanning"] = round(group['last_replanning_evaluations'].mean(), 3)
                std_row["Replanning"] = round(group['last_replanning_evaluations'].std(), 3)
            elif(name == "NSGAII_ConditionReplanningStrategy-_0-13.6795reusePortion=0.2_withSeed_1"):
                mean_row["Replanning (seed 0.2)"] = round(group['last_replanning_evaluations'].mean(), 3)
                std_row["Replanning (seed 0.2)"] = round(group['last_replanning_evaluations'].std(), 3)
           
        #print(f)
       # print(mean_row)
        mean_row["Option"] = f.split("@")[1].split("_errPerDisturbance")[0]
        mean = mean.append(mean_row, ignore_index = True)
        std_row["Option"] = f.split("@")[1].split(".")[0]
        std = std.append(std_row, ignore_index = True)
            # todo: median
            # todo: variance
print("Mean - Replanning time")
mean["Diff to no seed"] = (mean["Replanning (seed 0.2)"] - mean["Replanning"]) / mean["Replanning"] * 100
display(mean)

print("Standard Deviation - Replanning time")
display(std)
#print(std)
# todo: create table for each rq
# todo: create plot for each rq

# todo: in den CSVs: naive Planning -> naive Repair
# Out:
# Index(['variant', 'run', 'initial_planning_time',
#        'initial_planning_evaluations', 'initial_planning_objective',
#        'initial_post_disturbance_std', 'last_replanning_time',
#        'last_replanning_evaluations', 'overall_replanning_time',
#        'overall_replanning_evaluations', 'final_objective_value',
#        'failed_executions'],
#       dtype='object')
# Index(['variant', 'run', 'initial_planning_time',
#        'initial_planning_evaluations', 'initial_planning_objective',
#        'initial_post_disturbance_std', 'last_replanning_time',
#        'last_replanning_evaluations', 'overall_replanning_time',
#        'overall_replanning_evaluations', 'final_objective_value',
#        'failed_executions'],
#       dtype='object')
# Index(['variant', 'run', 'initial_planning_time',
#        'initial_planning_evaluations', 'initial_planning_objective',
#        'initial_post_disturbance_std', 'last_replanning_time',
#        'last_replanning_evaluations', 'overall_replanning_time',
#        'overall_replanning_evaluations', 'final_objective_value',
#        'failed_executions'],
#       dtype='object')
# Mean - Replanning time
#                             Option Replanning Replanning (seed 0.2)  \
# 0   REMOVE_STACKS_FIRST_10_PERCENT    18660.0              4053.333
# 1    REMOVE_STACKS_LAST_10_PERCENT      230.0               106.667
# 2  REMOVE_STACKS_MIDDLE_10_PERCENT   6196.667               833.333
#
#   Diff to no seed
# 0      -78.277958
# 1      -53.623043
# 2      -86.551916
# Standard Deviation - Replanning time
#                                               Option Replanning  \
# 0  REMOVE_STACKS_FIRST_10_PERCENT_errPerDisturban...   2233.846
# 1  REMOVE_STACKS_LAST_10_PERCENT_errPerDisturbance-5    182.228
# 2  REMOVE_STACKS_MIDDLE_10_PERCENT_errPerDisturba...   1586.687
#
#   Replanning (seed 0.2)
# 0              2761.775
# 1                25.371
# 2              1366.176

# %% [markdown]
# # RQ3: Parallel Replanning
# ### Predefined standard deviation ( >= 60% decrease from initial std + initialization approximate); Search until quality is sufficient (initial plan & replan after disturbance while system idle), search in parallel until Q1 = Q2 and T1 < T2

# %%
files = os.listdir(os.path.join('.', 'parallel_rq3'))
replan_time = pd.DataFrame(columns = ["Option", "Replanning", "Parallel Rep. 2", "Parallel Rep. 5", "Parallel Rep. 10"])
execution_steps = pd.DataFrame(columns =  ["Option", "Replanning", "Parallel Rep. 2", "Parallel Rep. 5", "Parallel Rep. 10"])
for f in files:
    if f.endswith("csv"):
        df = pd.read_csv(os.path.join('.', 'parallel_rq3', f))
        df_p = pd.read_csv(os.path.join('.', 'parallel_rq3', "parallel_results", f[:-4] + "_predictive.csv"))
        mean_replantime_row = {}
        mean_execsteps_row = {}

        for name, group in df.groupby(by='variant'):
            #print(f"\tVariant: {name}")
            #print(f"\t\tFinal objective (mean): {group['final_objective_value'].mean():.3f} ({group['final_objective_value'].std():.3f})\n")
            if(name == "NSGAII_ConditionReplanningStrategy-_0-10.9436_0"):
                mean_replantime_row["Replanning"] = round(group['last_replanning_time'].mean(), 3)

        for name, group in df_p.groupby(by=['variant', 'predicted_steps']):
            #print(f"\tVariant: {name}")
            #print(f"\t\tFinal objective (mean): {group['final_objective_value'].mean():.3f} ({group['final_objective_value'].std():.3f})\n")
            mean_replantime_row[f"Parallel Rep. {name[1]}"] = round(group['pred_plan_runtime'].mean(), 3)
            mean_execsteps_row["Replanning"] = round(mean([ast.literal_eval(g)[0] for g in group['idle_computed_objectives']]), 3)
            mean_execsteps_row[f"Parallel Rep. {name[1]}"] = round(mean([ast.literal_eval(g)[1]+name[1] for g in group['pred_plan_objectives']]), 3)

        
        #print(f)
       # print(mean_row)
        mean_replantime_row["Option"] = f.split("@")[1].split("_errPerDisturbance")[0]
        mean_execsteps_row["Option"] = f.split("@")[1].split("_errPerDisturbance")[0]
        replan_time = replan_time.append(mean_replantime_row, ignore_index = True)
        execution_steps = execution_steps.append(mean_execsteps_row, ignore_index = True)
        #std_row["Option"] = f.split("@")[1].split(".")[0]
        #std = std.append(std_row, ignore_index = True)
            # todo: median
            # todo: variance
print("Mean - Replanning time (in seconds)")
display(replan_time)

#mean["Replanning"] = (mean["Replanning"] - mean["Naive Repair"]) / mean["Naive Repair"] * 100
#mean.round({'Replanning': 1})
#mean["Replanning (seed 0.2)"] = (mean["Replanning (seed 0.2)"] - mean["Replanning"])/ mean["Replanning"] * 100
#mean.round(3)
#print("Mean - Replanning time (with seed) relative to plain replanning (in %)")
print("Mean - Planned steps after replanning (remaining 2/5/10 steps are included, respectively)")
display(execution_steps)

#print("Standard Deviation - Replanning time")
#display(std)
#print(std)
# todo: create table for each rq
# todo: create plot for each rq

# todo: in den CSVs: naive Planning -> naive Repair
# Out:
# Mean - Replanning time
#                             Option  Replanning  Parallel Rep. 2  \
# 0   REMOVE_STACKS_FIRST_10_PERCENT      15.011           31.441
# 1    REMOVE_STACKS_LAST_10_PERCENT       0.948           46.261
# 2  REMOVE_STACKS_MIDDLE_10_PERCENT       2.471            9.818
#
#    Parallel Rep. 5  Parallel Rep. 10
# 0           26.549            27.422
# 1           12.050               NaN
# 2            9.261            15.988
# Mean - Planned steps after replanning (remaining 2/5/10 steps are included, respectively)
#                             Option  Replanning  Parallel Rep. 2  \
# 0   REMOVE_STACKS_FIRST_10_PERCENT      73.167           63.500
# 1    REMOVE_STACKS_LAST_10_PERCENT      90.000           78.467
# 2  REMOVE_STACKS_MIDDLE_10_PERCENT      91.700           82.467
#
#    Parallel Rep. 5  Parallel Rep. 10
# 0           65.533            67.867
# 1           89.000               NaN
# 2           83.000            82.100
